# %% [markdown]
# <style>
# .jp-RenderedHTMLCommon table,
# .rendered_html table {
#   margin-left: 0 !important;
#   margin-right: auto !important;
# }
# .jp-RenderedHTMLCommon th,
# .jp-RenderedHTMLCommon td,
# .rendered_html th,
# .rendered_html td {
#   text-align: left !important;
# }
# </style>
#
# # 02 - Python, NumPy, and Pandas Foundations
#
# <div style="background:#F7FAFC; border:1px solid #D9E2EC; border-left:6px solid #2F80ED; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/goal.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Notebook Header</b><br>
# <b>Day:</b> Day 1 - EDA and preprocessing foundations<br>
# <b>Difficulty:</b> Beginner<br>
# <b>Estimated time:</b> 45-60 minutes<br>
# <b>Prerequisites:</b> Notebook 01 completed<br>
# <b>Output:</b> You will create and manipulate simple Python, NumPy, and Pandas objects.<br>
# <b>Next notebook:</b> Data inspection and cleaning
# </div>
#
# <details>
# <summary><b>Instructor talk track</b></summary>
#
# This notebook is about comfort. Learners should not memorize every function. They should understand that Python stores values, NumPy works well with numbers, and Pandas works well with tables.
#
# </details>
#
# ## <img src="../../../assets/icons/map.svg" width="22" style="vertical-align:middle; margin-right:6px;"> How to Use This Notebook
#
# For every concept, follow this rhythm:
#
# 1. Read why the concept matters.
# 2. Run one code cell.
# 3. Read the output carefully.
# 4. Explain the result in plain English.
# 5. Try one small change when suggested.
#
# <div style="background:#FFF8E1; border-left:6px solid #F2C94C; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/read-output.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Trainer Note</b><br>
# This notebook is the first real coding foundation. Keep the pace slow and ask learners to explain output before moving to the next concept.
# </div>
#
# ## <img src="../../../assets/icons/map.svg" width="22" style="vertical-align:middle; margin-right:6px;"> Learning Map
#
# By the end of this notebook, you should be able to:
#
# - Create Python variables
# - Use lists to store multiple values
# - Use dictionaries to store labeled values
# - Create NumPy arrays
# - Run simple NumPy calculations
# - Create Pandas Series and DataFrames
# - Select, filter, sort, and summarize table data
#
# ## <img src="../../../assets/icons/loop.svg" width="22" style="vertical-align:middle; margin-right:6px;"> Signature Learning Loop
#
# ```text
# QUESTION -> DATA -> CODE -> EVIDENCE -> DECISION
# ```

# %% [markdown]
# ## <img src="../../../assets/icons/concept.svg" width="22" style="vertical-align:middle; margin-right:6px;"> Concept 1: Python Variables
#
# <div style="background:#EAF3FF; border-left:6px solid #2F80ED; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/concept.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Concept</b><br>
# A variable is a name that stores a value.
# </div>
#
# ### Why this matters
#
# - Data work needs values stored with clear names.
# - Good variable names make code easier to read.
# - Variables can store text, numbers, and other objects.
#
# <div style="background:#E9F8EF; border-left:6px solid #27AE60; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/code.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Code Lab</b><br>
# Create a few variables for a customer purchase example.
# </div>
#
# <div style="background:#FFF8E1; border-left:6px solid #F2C94C; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/read-output.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Read the Output</b><br>
# Check how each variable name makes the stored value understandable.
# </div>

# %%
customer_name = "Asha"
city = "Mumbai"
monthly_spend = 1200
visits_per_month = 4

print("Customer:", customer_name)
print("City:", city)
print("Monthly spend:", monthly_spend)
print("Visits per month:", visits_per_month)

# %% [markdown]
# ## <img src="../../../assets/icons/concept.svg" width="22" style="vertical-align:middle; margin-right:6px;"> Concept 2: Python Lists
#
# <div style="background:#EAF3FF; border-left:6px solid #2F80ED; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/concept.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Concept</b><br>
# A list stores multiple values in order.
# </div>
#
# ### Why this matters
#
# - Data work often starts with many values, not one value.
# - A list is useful when order matters.
# - Lists are a simple bridge before NumPy arrays and Pandas columns.
#
# ### List basics
#
# - Lists use square brackets: `[]`
# - The first item is at position `0`
# - `len()` counts how many items are present
# - `sum()` adds numeric items
#
# <div style="background:#E9F8EF; border-left:6px solid #27AE60; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/code.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Code Lab</b><br>
# Create a list of monthly purchase amounts and summarize it.
# </div>
#
# <div style="background:#FFF8E1; border-left:6px solid #F2C94C; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/read-output.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Read the Output</b><br>
# Check the first value, the number of values, and the total. Connect each output line to one function or index operation.
# </div>
#
# <div style="background:#F7FBFF; border-left:6px solid #56CCF2; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/practice.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Try It</b><br>
# Change one value in the list and predict how the total will change before running the cell again.
# </div>

# %%
purchase_amounts = [1200, 850, 1450, 700, 2200]

print("All purchases:", purchase_amounts)
print("First purchase:", purchase_amounts[0])
print("Number of purchases:", len(purchase_amounts))
print("Total purchase amount:", sum(purchase_amounts))

# %% [markdown]
# ## <img src="../../../assets/icons/concept.svg" width="22" style="vertical-align:middle; margin-right:6px;"> Concept 3: Python Dictionaries
#
# <div style="background:#EAF3FF; border-left:6px solid #2F80ED; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/concept.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Concept</b><br>
# A dictionary stores key-value pairs.
# </div>
#
# ### Why dictionaries matter
#
# - They attach labels to values.
# - One dictionary can represent one record.
# - A row in a table is similar to a labeled record.
# - Dictionaries make data easier to understand than unlabeled lists.
#
# ### Dictionary language
#
# - Key: the label, such as `city`
# - Value: the stored data, such as `Mumbai`
# - Key-value pair: one label and its value together
#
# <div style="background:#E9F8EF; border-left:6px solid #27AE60; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/code.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Code Lab</b><br>
# Create one customer record as a dictionary.
# </div>
#
# <div style="background:#FFF8E1; border-left:6px solid #F2C94C; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/read-output.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Read the Output</b><br>
# Notice that `customer["city"]` returns the value stored under the `city` key.
# </div>
#
# <div style="background:#F7FBFF; border-left:6px solid #56CCF2; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/practice.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Try It</b><br>
# Add one new key called `membership` and give the customer a value such as `Gold`.
# </div>

# %%
customer = {
    "customer_id": 101,
    "name": "Asha",
    "city": "Mumbai",
    "monthly_spend": 1200,
    "visits_per_month": 4,
}

print(customer)
print("Customer city:", customer["city"])
print("Monthly spend:", customer["monthly_spend"])

# %% [markdown]
# ## <img src="../../../assets/icons/practice.svg" width="22" style="vertical-align:middle; margin-right:6px;"> Checkpoint 1: Python Objects
#
# Answer these before continuing:
#
# 1. What is the purpose of a variable?
# 2. When would you use a list?
# 3. Why is a dictionary easier to understand than an unlabeled list?
#
# <div style="background:#FFF8E1; border-left:6px solid #F2C94C; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/read-output.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Expected thinking</b><br>
# Variables store one object, lists store ordered values, and dictionaries store labeled values.
# </div>

# %% [markdown]
# ## <img src="../../../assets/icons/concept.svg" width="22" style="vertical-align:middle; margin-right:6px;"> Concept 4: NumPy Arrays
#
# <div style="background:#EAF3FF; border-left:6px solid #2F80ED; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/concept.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Concept</b><br>
# A NumPy array stores numeric values and supports fast calculations.
# </div>
#
# ### Why NumPy is useful
#
# - It is efficient for numerical data.
# - It supports element-wise operations.
# - It gives useful methods such as `.mean()` and `.max()`.
# - It is used internally by many data science libraries.
#
# ### List vs array
#
# - A Python list is general-purpose.
# - A NumPy array is designed for numerical calculation.
#
# <div style="background:#E9F8EF; border-left:6px solid #27AE60; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/code.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Code Lab</b><br>
# Convert purchase values into a NumPy array and calculate simple summaries.
# </div>
#
# <div style="background:#FFF8E1; border-left:6px solid #F2C94C; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/read-output.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Read the Output</b><br>
# Confirm that `.mean()` gives the average spend and `.max()` gives the highest spend.
# </div>

# %%
import numpy as np

spend_array = np.array([1200, 850, 1450, 700, 2200])

print("Array:", spend_array)
print("Type:", type(spend_array))
print("Average spend:", spend_array.mean())
print("Highest spend:", spend_array.max())

# %% [markdown]
# ## <img src="../../../assets/icons/concept.svg" width="22" style="vertical-align:middle; margin-right:6px;"> Concept 5: NumPy Element-Wise Operations
#
# <div style="background:#EAF3FF; border-left:6px solid #2F80ED; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/concept.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Concept</b><br>
# Element-wise operation means the calculation is applied to every value in the array.
# </div>
#
# ### Why this matters
#
# In Data Science, we often apply the same calculation to many rows.
#
# Example:
#
# - Increase every spend value by 10 percent
# - Convert every temperature from Celsius to Fahrenheit
# - Apply the same tax rate to every amount
#
# NumPy does this directly without writing a manual loop.
#
# <div style="background:#E9F8EF; border-left:6px solid #27AE60; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/code.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Code Lab</b><br>
# Multiply every value in the spend array by `1.10`.
# </div>
#
# <div style="background:#FFF8E1; border-left:6px solid #F2C94C; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/read-output.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Read the Output</b><br>
# Each output value should be 10 percent higher than the matching original value.
# </div>
#
# <div style="background:#F7FBFF; border-left:6px solid #56CCF2; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/practice.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Try It</b><br>
# Change `1.10` to `0.90` and explain what the new operation means.
# </div>

# %%
increased_spend = spend_array * 1.10

print("Original spend:", spend_array)
print("After 10 percent increase:", increased_spend.round(1))

# %% [markdown]
# ## <img src="../../../assets/icons/concept.svg" width="22" style="vertical-align:middle; margin-right:6px;"> Concept 6: Pandas Series
#
# <div style="background:#EAF3FF; border-left:6px solid #2F80ED; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/concept.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Concept</b><br>
# A Pandas Series is one labeled column of data.
# </div>
#
# ### Why this matters
#
# - A dataset column can be handled as a Series.
# - Series objects have labels, values, and useful summary methods.
# - Many Pandas operations return a Series before returning a full table.
#
# ### Simple memory line
#
# - Series = one column
# - DataFrame = full table
#
# <div style="background:#E9F8EF; border-left:6px solid #27AE60; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/code.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Code Lab</b><br>
# Create a Pandas Series for membership types.
# </div>
#
# <div style="background:#FFF8E1; border-left:6px solid #F2C94C; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/read-output.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Read the Output</b><br>
# Notice the index on the left and the membership values on the right.
# </div>

# %%
import pandas as pd

membership_series = pd.Series(["Gold", "Silver", "Gold", "Bronze", "Silver"], name="membership")

membership_series

# %% [markdown]
# ## <img src="../../../assets/icons/concept.svg" width="22" style="vertical-align:middle; margin-right:6px;"> Concept 7: Pandas DataFrame
#
# <div style="background:#EAF3FF; border-left:6px solid #2F80ED; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/concept.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Concept</b><br>
# A DataFrame is a table made of rows and columns.
# </div>
#
# ### Why this matters
#
# Most tabular data in Data Science is handled as a DataFrame.
#
# A DataFrame lets us:
#
# - View rows and columns
# - Select useful columns
# - Filter matching rows
# - Sort records
# - Add calculated columns
# - Group and summarize data
#
# ### In this example
#
# - One row is one customer.
# - Each column stores one detail about the customer.
# - This small table is easy to inspect manually.
#
# <div style="background:#E9F8EF; border-left:6px solid #27AE60; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/code.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Code Lab</b><br>
# Create a customer purchase DataFrame.
# </div>
#
# <div style="background:#FFF8E1; border-left:6px solid #F2C94C; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/read-output.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Read the Output</b><br>
# Count the rows and columns visually. Identify which columns are text and which columns are numeric.
# </div>

# %%
customers = pd.DataFrame({
    "customer_id": [101, 102, 103, 104, 105, 106],
    "name": ["Asha", "Ravi", "Meera", "John", "Fatima", "Chen"],
    "city": ["Mumbai", "Delhi", "Chennai", "Mumbai", "Delhi", "Chennai"],
    "membership": ["Gold", "Silver", "Gold", "Bronze", "Silver", "Gold"],
    "monthly_spend": [1200, 850, 1450, 700, 2200, 1600],
    "visits_per_month": [4, 3, 5, 2, 6, 5],
})

customers

# %% [markdown]
# ## <img src="../../../assets/icons/concept.svg" width="22" style="vertical-align:middle; margin-right:6px;"> Concept 8: Selecting Columns
#
# <div style="background:#EAF3FF; border-left:6px solid #2F80ED; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/concept.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Concept</b><br>
# Selecting columns means choosing only the information we need from a table.
# </div>
#
# ### Why this matters
#
# - Real datasets can have many columns.
# - We often inspect only a few columns at a time.
# - This keeps analysis focused.
# - It also reduces noise when explaining results.
#
# ### Important syntax
#
# Use double brackets when selecting multiple columns:
#
# ```text
# customers[["name", "city", "monthly_spend"]]
# ```
#
# <div style="background:#E9F8EF; border-left:6px solid #27AE60; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/code.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Code Lab</b><br>
# Select customer name, city, and monthly spend.
# </div>
#
# <div style="background:#FFF8E1; border-left:6px solid #F2C94C; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/read-output.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Read the Output</b><br>
# The number of rows should stay the same, but the number of columns should reduce.
# </div>

# %%
selected_columns = customers[["name", "city", "monthly_spend"]]

selected_columns

# %% [markdown]
# ## <img src="../../../assets/icons/concept.svg" width="22" style="vertical-align:middle; margin-right:6px;"> Concept 9: Filtering Rows
#
# <div style="background:#EAF3FF; border-left:6px solid #2F80ED; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/concept.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Concept</b><br>
# Filtering keeps rows that match a condition.
# </div>
#
# ### Why this matters
#
# Filtering helps us focus on records that answer a specific question.
#
# Example questions:
#
# - Which customers spend more than 1000?
# - Which customers are from Delhi?
# - Which customers visit at least 5 times per month?
#
# ### Example condition
#
# Keep customers whose monthly spend is greater than `1000`.
#
# <div style="background:#E9F8EF; border-left:6px solid #27AE60; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/code.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Code Lab</b><br>
# Filter high-spending customers.
# </div>
#
# <div style="background:#FFF8E1; border-left:6px solid #F2C94C; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/read-output.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Read the Output</b><br>
# Every remaining row should have `monthly_spend` greater than `1000`.
# </div>
#
# <div style="background:#F7FBFF; border-left:6px solid #56CCF2; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/practice.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Try It</b><br>
# Change the condition to keep customers with at least `5` visits per month.
# </div>

# %%
high_spend_customers = customers[customers["monthly_spend"] > 1000]

high_spend_customers

# %% [markdown]
# ## <img src="../../../assets/icons/concept.svg" width="22" style="vertical-align:middle; margin-right:6px;"> Concept 10: Sorting Data
#
# <div style="background:#EAF3FF; border-left:6px solid #2F80ED; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/concept.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Concept</b><br>
# Sorting arranges rows based on a column.
# </div>
#
# ### Why this matters
#
# - Sorting helps find highest and lowest values quickly.
# - It is useful before writing observations.
# - It helps confirm whether a summary makes sense.
#
# ### Sorting direction
#
# - `ascending=True` means low to high
# - `ascending=False` means high to low
#
# <div style="background:#E9F8EF; border-left:6px solid #27AE60; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/code.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Code Lab</b><br>
# Sort customers by monthly spend from highest to lowest.
# </div>
#
# <div style="background:#FFF8E1; border-left:6px solid #F2C94C; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/read-output.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Read the Output</b><br>
# The first row should show the highest monthly spend. The last row should show the lowest monthly spend.
# </div>

# %%
customers_sorted = customers.sort_values("monthly_spend", ascending=False)

customers_sorted

# %% [markdown]
# ## <img src="../../../assets/icons/concept.svg" width="22" style="vertical-align:middle; margin-right:6px;"> Concept 11: Adding a New Column
#
# <div style="background:#EAF3FF; border-left:6px solid #2F80ED; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/concept.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Concept</b><br>
# A new column can be created from existing columns.
# </div>
#
# ### Why this matters
#
# Data Science often creates useful signals from existing data.
#
# Example:
#
# If we know monthly spend and visits per month, we can calculate spend per visit.
#
# This new column may answer a better question:
#
# ```text
# How much does a customer spend during each visit on average?
# ```
#
# <div style="background:#E9F8EF; border-left:6px solid #27AE60; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/code.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Code Lab</b><br>
# Create a new column called `spend_per_visit`.
# </div>
#
# <div style="background:#FFF8E1; border-left:6px solid #F2C94C; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/read-output.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Read the Output</b><br>
# A new column should appear at the end of the table. Check one row manually to confirm the calculation.
# </div>

# %%
customers["spend_per_visit"] = customers["monthly_spend"] / customers["visits_per_month"]

customers

# %% [markdown]
# ## <img src="../../../assets/icons/concept.svg" width="22" style="vertical-align:middle; margin-right:6px;"> Concept 12: Grouping and Summarizing
#
# <div style="background:#EAF3FF; border-left:6px solid #2F80ED; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/concept.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Concept</b><br>
# Grouping means splitting data into categories and calculating summaries for each category.
# </div>
#
# ### Why this matters
#
# Grouping is one of the most important Pandas skills for EDA.
#
# It helps answer questions such as:
#
# - Which membership group spends more?
# - Which city has higher average spend?
# - Which group visits more often?
#
# ### Example question
#
# What is the average monthly spend for each membership type?
#
# <div style="background:#E9F8EF; border-left:6px solid #27AE60; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/code.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Code Lab</b><br>
# Group customers by membership and calculate average monthly spend.
# </div>
#
# <div style="background:#FFF8E1; border-left:6px solid #F2C94C; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/read-output.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Read the Output</b><br>
# Each row in the output is one membership group. The summary value is the average monthly spend for that group.
# </div>
#
# <div style="background:#F7FBFF; border-left:6px solid #56CCF2; padding:14px; border-radius:6px;">
# <img src="../../../assets/icons/practice.svg" width="22" style="vertical-align:middle; margin-right:6px;"><b>Try It</b><br>
# Change the grouping column from `membership` to `city` and compare the result.
# </div>

# %%
membership_summary = customers.groupby("membership")["monthly_spend"].mean().reset_index()

membership_summary

# %% [markdown]
# ## <img src="../../../assets/icons/recap.svg" width="22" style="vertical-align:middle; margin-right:6px;"> Concept Summary Table
#
# <table style="margin-left:0; margin-right:auto; border-collapse:collapse; text-align:left;">
#   <thead>
#     <tr>
#       <th style="text-align:left; padding:6px 12px;">Concept</th>
#       <th style="text-align:left; padding:6px 12px;">Simple meaning</th>
#       <th style="text-align:left; padding:6px 12px;">Example</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr><td style="text-align:left; padding:6px 12px;">Variable</td><td style="text-align:left; padding:6px 12px;">Named storage</td><td style="text-align:left; padding:6px 12px;"><code>monthly_spend = 1200</code></td></tr>
#     <tr><td style="text-align:left; padding:6px 12px;">List</td><td style="text-align:left; padding:6px 12px;">Ordered collection</td><td style="text-align:left; padding:6px 12px;"><code>[1200, 850, 1450]</code></td></tr>
#     <tr><td style="text-align:left; padding:6px 12px;">Dictionary</td><td style="text-align:left; padding:6px 12px;">Labeled values</td><td style="text-align:left; padding:6px 12px;"><code>{"city": "Mumbai"}</code></td></tr>
#     <tr><td style="text-align:left; padding:6px 12px;">NumPy array</td><td style="text-align:left; padding:6px 12px;">Numeric collection</td><td style="text-align:left; padding:6px 12px;"><code>np.array([...])</code></td></tr>
#     <tr><td style="text-align:left; padding:6px 12px;">Series</td><td style="text-align:left; padding:6px 12px;">One Pandas column</td><td style="text-align:left; padding:6px 12px;"><code>pd.Series(...)</code></td></tr>
#     <tr><td style="text-align:left; padding:6px 12px;">DataFrame</td><td style="text-align:left; padding:6px 12px;">Pandas table</td><td style="text-align:left; padding:6px 12px;"><code>pd.DataFrame(...)</code></td></tr>
#   </tbody>
# </table>

# %% [markdown]
# ## <img src="../../../assets/icons/caution.svg" width="22" style="vertical-align:middle; margin-right:6px;"> Common Mistakes to Avoid
#
# <div style="background:#FFECEC; border-left:6px solid #EB5757; padding:14px; border-radius:6px;">
# <b>Read this before practice.</b>
# </div>
#
# - Forgetting that Python positions start at `0`, not `1`.
# - Using unclear variable names like `x` when a clearer name is possible.
# - Confusing a Pandas Series with a DataFrame.
# - Forgetting double brackets when selecting multiple DataFrame columns.
# - Running cells out of order and then wondering why a variable is missing.

# %% [markdown]
# ## <img src="../../../assets/icons/practice.svg" width="22" style="vertical-align:middle; margin-right:6px;"> Practice Task
#
# Complete these tasks:
#
# 1. Add a new customer to the `customers` DataFrame.
# 2. Select only `name`, `membership`, and `visits_per_month`.
# 3. Filter customers from `Delhi`.
# 4. Sort customers by `visits_per_month` from highest to lowest.
# 5. Create a new column called `annual_spend` by multiplying `monthly_spend` by `12`.
# 6. Group by `city` and calculate average `monthly_spend`.
#
# ## <img src="../../../assets/icons/practice.svg" width="22" style="vertical-align:middle; margin-right:6px;"> Exit Ticket
#
# Answer these before closing the notebook:
#
# 1. What is the difference between a list and a dictionary?
# 2. What is the difference between a Series and a DataFrame?
# 3. What does filtering do?
# 4. What does grouping do?
# 5. Why are clear column names important?
#
# ## <img src="../../../assets/icons/recap.svg" width="22" style="vertical-align:middle; margin-right:6px;"> Ready for the Next Notebook
#
# You are ready for the next notebook if you can:
#
# - Create a small DataFrame.
# - Select columns from a DataFrame.
# - Filter rows using a condition.
# - Sort rows by a column.
# - Add a calculated column.
# - Group data and calculate a summary.
